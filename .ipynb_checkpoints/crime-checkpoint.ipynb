# %%
import pandas as pd
import geopandas as gpd

# %%
import seaborn as sns
sns.set(style="ticks")

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import scipy
from scipy.stats.stats import pearsonr

# %%
df = pd.read_csv('hate_crimes.csv')

# %%
df.head()
# Out:
#         state  median_household_income  share_unemployed_seasonal  \
# 0     Alabama                    42278                      0.060
# 1      Alaska                    67629                      0.064
# 2     Arizona                    49254                      0.063
# 3    Arkansas                    44922                      0.052
# 4  California                    60487                      0.059
#
#    share_population_in_metro_areas  share_population_with_high_school_degree  \
# 0                             0.64                                     0.821
# 1                             0.63                                     0.914
# 2                             0.90                                     0.842
# 3                             0.69                                     0.824
# 4                             0.97                                     0.806
#
#    share_non_citizen  share_white_poverty  gini_index  share_non_white  \
# ...

# %%
df.describe()
# Out:
#        median_household_income  share_unemployed_seasonal  \
# count                51.000000                  51.000000
# mean              55223.607843                   0.049569
# std                9208.478170                   0.010698
# min               35521.000000                   0.028000
# 25%               48657.000000                   0.042000
# 50%               54916.000000                   0.051000
# 75%               60719.000000                   0.057500
# max               76165.000000                   0.073000
#
#        share_population_in_metro_areas  \
# count                        51.000000
# mean                          0.750196
# std                           0.181587
# min                           0.310000
# 25%                           0.630000
# 50%                           0.790000
# 75%                           0.895000
# max                           1.000000
#
#        share_population_with_high_school_degree  share_non_citizen  \
# ...

# %%
df.median_household_income.plot(kind='bar')

# %%
sns.pairplot(df)

# %%
corr = df.corr()
corr
# Pearson correlation coefficient: Assumptions are your data is normally distributed, you have continuous numeric variables, and your variables are linearly related.
# Out:
#                                           median_household_income  \
# median_household_income                                  1.000000
# share_unemployed_seasonal                               -0.376722
# share_population_in_metro_areas                          0.286480
# share_population_with_high_school_degree                 0.653490
# share_non_citizen                                        0.302288
# share_white_poverty                                     -0.818045
# gini_index                                              -0.178821
# share_non_white                                          0.103775
# share_voters_voted_trump                                -0.597528
# hate_crimes_per_100k_splc                                0.350714
# avg_hatecrimes_per_100k_fbi                              0.318246
#
#                                           share_unemployed_seasonal  \
# median_household_income                                   -0.376722
# ...

# %%
sns.heatmap(corr, xticklabels=corr.columns.values, yticklabels=corr.columns.values)
#Strong correlations: income - degree, income - poverty, income - support Trump

# %%
income = df['median_household_income']
unemployed = df['share_unemployed_seasonal']
income_Unemployed_crosstab = pd.crosstab(income, unemployed)
income_Unemployed_crosstab
# Out:
# share_unemployed_seasonal  0.028  0.029  0.034  0.035  0.036  0.037  0.038  \
# median_household_income
# 35521                          0      0      0      0      0      0      0
# 39552                          0      0      0      0      0      0      0
# 42278                          0      0      0      0      0      0      0
# 42406                          0      0      0      0      0      0      0
# 42786                          0      0      0      0      0      0      0
# 43716                          0      0      0      0      0      0      0
# 44922                          0      0      0      0      0      0      0
# 44929                          0      0      0      0      0      0      0
# 46140                          0      0      0      0      0      0      0
# 46686                          0      0      0      0      0      0      0
# 46784                          0      0      0      0      0      0      0
# ...
